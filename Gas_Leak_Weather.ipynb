# %%
import pandas as pd

# %%
df = pd.read_csv("nycweatherdata.csv", parse_dates=True)

# %%
df.head()
# Out:
#        STATION    DATE  TMAX  TMIN
# 0  USW00094728  1/1/13    40    26
# 1  USW00094728  1/2/13    33    22
# 2  USW00094728  1/3/13    32    24
# 3  USW00094728  1/4/13    37    30
# 4  USW00094728  1/5/13    42    32

# %%
df.head()
# Out:
#        STATION    DATE  TMAX  TMIN
# 0  USW00094728  1/1/13    40    26
# 1  USW00094728  1/2/13    33    22
# 2  USW00094728  1/3/13    32    24
# 3  USW00094728  1/4/13    37    30
# 4  USW00094728  1/5/13    42    32

# %%
df.columns
# Out:
# Index(['STATION', 'DATE', 'TMAX', 'TMIN'], dtype='object')

# %%
for i, row_weather in df.iterrows():
    print(row_weather.TMAX, row_weather.DATE)
# Out:
# 40 1/1/13
# 33 1/2/13
# 32 1/3/13
# 37 1/4/13
# 42 1/5/13
# 46 1/6/13
# 45 1/7/13
# 48 1/8/13
# 49 1/9/13
# 47 1/10/13
# 46 1/11/13
# 47 1/12/13
# 50 1/13/13
# 56 1/14/13
# 38 1/15/13
# 37 1/16/13
# 43 1/17/13
# 35 1/18/13
# 51 1/19/13
# 53 1/20/13
# 32 1/21/13
# 27 1/22/13
# 20 1/23/13
# 22 1/24/13
# 24 1/25/13
# 27 1/26/13
# 34 1/27/13
# 36 1/28/13
# 49 1/29/13
# 59 1/30/13
# 61 1/31/13
# 31 2/1/13
# 29 2/2/13
# 30 2/3/13
# 30 2/4/13
# 32 2/5/13
# 39 2/6/13
# 32 2/7/13
# 34 2/8/13
# 32 2/9/13
# 36 2/10/13
# 45 2/11/13
# 44 2/12/13
# 44 2/13/13
# 46 2/14/13
# 55 2/15/13
# 41 2/16/13
# 32 2/17/13
# 35 2/18/13
# 49 2/19/13
# 38 2/20/13
# 34 2/21/13
# 38 2/22/13
# 42 2/23/13
# 47 2/24/13
# 45 2/25/13
# 44 2/26/13
# 47 2/27/13
# 51 2/28/13
# 45 3/1/13
# 40 3/2/13
# 40 3/3/13
# 42 3/4/13
# 49 3/5/13
# 42 3/6/13
# 38 3/7/13
# 42 3/8/13
# 55 3/9/13
# 50 3/10/13
# 54 3/11/13
# 57 3/12/13
# 52 3/13/13
# 41 3/14/13
# 47 3/15/13
# 41 3/16/13
# 38 3/17/13
# 35 3/18/13
# 43 3/19/13
# 45 3/20/13
# ...

# %%
df
